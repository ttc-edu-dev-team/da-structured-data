# %% [markdown]
# ![](https://pandas.pydata.org/static/img/pandas_white.svg)
# ![](http://wesmckinney.com/images/wes-2017-01-12-small.png)
# created by Wes McKinney ( http://wesmckinney.com )
#
#
# # Prerequisites4 : Pandas

# %% [markdown]
# # Learning Plan

# %% [markdown]
# ### Lesson 4-1: Pandas Basics
# In this lesson, you learn 1)DataFrame 2)Series 3)index 4)columns .
#
# ### Lesson 4-2: Indexing
# In this lesson, you learn 1).head() 2).tail() 3)['column'] 4).column 5)[['column1', 'column2']] 6).loc[] 7)[lambda x: x.column =='x'] 8).isin() .
#
# ### Lesson 4-3: Groupby
# In this lesson, you learn 1)groupby('key')['column'].mean() 2).size() 3).sum() 4).max() 5).min() .

# %% [markdown]
# ### Lesson 4-4: Assign
# In this lesson, you learn 1).assign(new_column = lambda x: x.column ...) .
#
# ### Lesson 4-5: Method Chaining
# In this lesson, you learn 1)() 2).pipe .
#
# ### Lesson 4-6 Pandas 전처리 메소드
# In this lesson, you learn panda preprocessing methods.
#
# ### Lesson 4-6: Pandas Heuristics
# In this lesson, you learn 1)Naming 2)Data-Analytics Steps 3)Don't use for loop .

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Lesson 4-1: Pandas Basics

# %% [markdown]
# ## Python = General Programming Language 로 탄생했으나...

# %% [markdown]
# ## Python = Programming Language for Data Analytics 로 인식되고 있음.

# %% [markdown]
# ## Pandas = Data Analytics(데이터 분석) 을 위한 Python 라이브러리

# %% [markdown]
# ## Data = ?

# %% [markdown]
# ## Data = [Structured Data] + [Unstructured Data]
# ## Data = [Tabuler Data] + [Image, Text, Audio, Video]
# ## Data = [20%] + [80%]

# %% [markdown]
# ## Pandas 가 다루는 Data = 정형 데이터(Structured Data) = Table 형태 데이터

# %% [markdown]
# ## Data Analytics = Table 형태의 데이터를 다루는 영역

# %% [markdown]
# ## Pandas의 두가지 데이터 타입

# %% [markdown]
# ### * DataFrame
# ### * Series

# %% [markdown]
# ### 4-1-1 : Pandas DataFrame : 테이블

# %%
import pandas as pd

# %%
filename = '/content/drive/My Drive/da-structured-data/data/pandas/users.dat'
#filename = './data/pandas/users.dat'

# %%
unames = ['user_id', 'gender', 'age', 'occupation', 'zip'] 
users = pd.read_table(filename, sep='::', header=None, names=unames, engine='python', index_col='user_id')

# %%
users.head()
# Out:
#         gender  age  occupation    zip
# user_id
# 1            F    1          10  48067
# 2            M   56          16  70072
# 3            M   25          15  55117
# 4            M   45           7  02460
# 5            M   25          20  55455

# %% [markdown]
# ### 4-1-1 : DataFrame 의 index 와 colums

# %% [markdown]
# ![](https://github.com/ttc-edu-dev-team/da-structured-data/blob/main/assets/images/p4-1-1_pandas_dataframe_index_and_columns.png?raw=true)

# %% [markdown]
# ### 4-1-3 : DataFrame 의 행 | 열 한 줄 : Series

# %% [markdown]
# ![](https://github.com/ttc-edu-dev-team/da-structured-data/blob/main/assets/images/p4-1-2_pandas_dataframe_series.png?raw=true)

# %%
users['age'].head()
# Out:
# user_id
# 1     1
# 2    56
# 3    25
# 4    45
# 5    25
# Name: age, dtype: int64

# %%
users.loc[3]
# Out:
# gender            M
# age              25
# occupation       15
# zip           55117
# Name: 3, dtype: object

# %% [markdown]
# ### 4-1-4 : Series 의 index

# %% [markdown]
# ![](https://github.com/ttc-edu-dev-team/da-structured-data/blob/main/assets/images/p4-1-3_pandas_dataframe_series_index.png?raw=true)

# %% [markdown]
# ### 4-1-5: DataFrame vs Series
# * DataFrame = Matrix with labels
# * Series = Vector with labels

# %% [markdown]
# ![](https://github.com/ttc-edu-dev-team/da-structured-data/blob/main/assets/images/p4-1-4_matrix_vs_vector.png?raw=true)
# [ref : mathsisfun.com](https://www.mathsisfun.com/algebra/scalar-vector-matrix.html)

# %% [markdown]
# ### 4-1-6 : Series 생성하기

# %%
pd.Series([1, 2, 3, 4])
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %%
a = [1, 2, 3, 4]

# %%
pd.Series(a)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %% [markdown]
# ### 4-1-7 : DataFrame 생성하기

# %% [markdown]
# #### 첫번째 방법, List 사용해서 생성하기

# %%
company_list = [['삼성전자', 81500, '반도체'],
           ['SK하이닉스', 132500, '반도체'],
           ['NAVER', 379000, '포털']]

# %%
pd.DataFrame(company_list)
# Out:
#         0       1    2
# 0    삼성전자   81500  반도체
# 1  SK하이닉스  132500  반도체
# 2   NAVER  379000   포털

# %%
df = pd.DataFrame(company_list)

# %%
df
# Out:
#         0       1    2
# 0    삼성전자   81500  반도체
# 1  SK하이닉스  132500  반도체
# 2   NAVER  379000   포털

# %%
df.columns = ['종목명', '주가', '분류']
df
# Out:
#       종목명      주가   분류
# 0    삼성전자   81500  반도체
# 1  SK하이닉스  132500  반도체
# 2   NAVER  379000   포털

# %% [markdown]
# #### 두번째 방법, Dictionary를 사용해서 생성하기

# %%
company_dict = {'종목명':['삼성전자', 'SK하이닉스', 'NAVER'],
           '주가':[81500, 132500, 379000],
           '분류':['반도체', '반도체', '포털']}

# %%
df_dict = pd.DataFrame(company_dict)
df_dict
# Out:
#       종목명      주가   분류
# 0    삼성전자   81500  반도체
# 1  SK하이닉스  132500  반도체
# 2   NAVER  379000   포털

# %% [markdown]
# ### 4-1-8 :  index를 특정 column으로 지정하는 방법

# %%
df.index = df['종목명']
df
# Out:
#            종목명      주가   분류
# 종목명
# 삼성전자      삼성전자   81500  반도체
# SK하이닉스  SK하이닉스  132500  반도체
# NAVER    NAVER  379000   포털

# %%
df['주가']
# Out:
# 종목명
# 삼성전자       81500
# SK하이닉스    132500
# NAVER     379000
# Name: 주가, dtype: int64

# %%
type(df['주가'])
# Out:
# pandas.core.series.Series

# %% [markdown]
# ### 4-1-9 : CSV 파일 읽어오기

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
filename = '/content/drive/My Drive/da-structured-data/data/pandas/naver_finance_kospi_1-200.csv'
#filename = './data/pandas/naver_finance_kospi_1-200.csv'

# %%
pd.read_csv(filename, index_col = 0)
# Out:
#              종목명      현재가    전일비     등락률  ...  외국인비율         거래량     PER    ROE
# 번호                                        ...
# 1           삼성전자   81,500    500   0.62%  ...  54.68  11,918,571   21.22   9.99
# 2         SK하이닉스  132,500  1,000  -0.75%  ...  50.03   3,441,826   20.28   9.53
# 3          NAVER  379,000  8,000  -2.07%  ...  57.17     522,859   62.16  15.22
# 4          삼성전자우   73,300    400   0.55%  ...  78.11     656,347   19.08    NaN
# 5           LG화학  787,000  3,000   0.38%  ...  44.26     383,416  120.17   2.93
# ..           ...      ...    ...     ...  ...    ...         ...     ...    ...
# 196         LG상사   29,150    850   3.00%  ...  26.04     300,092     3.8  23.72
# 197         보령제약   21,450    550  -2.50%  ...   6.71     383,355   40.47   8.62
# 198  TIGER 단기통안채  100,125      5   0.00%  ...   1.08       1,596     NaN    NaN
# 199        금호타이어    3,780     20  -0.53%  ...   5.25     173,651  -13.08  -6.74
# ...

# %% [markdown]
# ### 4-1-10 : 엑셀 파일 읽어오기

# %%
# !pip install xlrd
# Out:
# ...
#     100% |████████████████████████████████| 102kB 1.5MB/s a 0:00:011
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
filename = '/content/drive/My Drive/da-structured-data/data/pandas/naver_finance_kospi_1-200.xls'
#filename = './data/pandas/naver_finance_kospi_1-200.xls'

# %%
pd.read_excel(filename)
# Out:
#        N          종목명     현재가   전일비  ...  외국인비율       거래량     PER    ROE
# 0      1         삼성전자   81500   500  ...  54.68  11918571   21.22   9.99
# 1      2       SK하이닉스  132500  1000  ...  50.03   3441826   20.28   9.53
# 2      3        NAVER  379000  8000  ...  57.17    522859   62.16  15.22
# 3      4        삼성전자우   73300   400  ...  78.11    656347   19.08    NaN
# 4      5         LG화학  787000  3000  ...  44.26    383416  120.17   2.93
# ..   ...          ...     ...   ...  ...    ...       ...     ...    ...
# 195  196         LG상사   29150   850  ...  26.04    300092    3.80  23.72
# 196  197         보령제약   21450   550  ...   6.71    383355   40.47   8.62
# 197  198  TIGER 단기통안채  100125     5  ...   1.08      1596     NaN    NaN
# 198  199        금호타이어    3780    20  ...   5.25    173651  -13.08  -6.74
# 199  200         세방전지   76800  1400  ...  24.56     84641   16.23   6.14
#
# [200 rows x 12 columns]

# %% [markdown]
# ### 4-1-11 : DataFrame 기본정보 보기

# %%
filename = '/content/drive/My Drive/da-structured-data/data/pandas/naver_finance_kospi_1-200.csv'
#filename = './data/pandas/naver_finance_kospi_1-200.xls'
df = pd.read_csv(filename)
df
# Out:
#       번호          종목명      현재가    전일비  ...  외국인비율         거래량     PER    ROE
# 0      1         삼성전자   81,500    500  ...  54.68  11,918,571   21.22   9.99
# 1      2       SK하이닉스  132,500  1,000  ...  50.03   3,441,826   20.28   9.53
# 2      3        NAVER  379,000  8,000  ...  57.17     522,859   62.16  15.22
# 3      4        삼성전자우   73,300    400  ...  78.11     656,347   19.08    NaN
# 4      5         LG화학  787,000  3,000  ...  44.26     383,416  120.17   2.93
# ..   ...          ...      ...    ...  ...    ...         ...     ...    ...
# 195  196         LG상사   29,150    850  ...  26.04     300,092     3.8  23.72
# 196  197         보령제약   21,450    550  ...   6.71     383,355   40.47   8.62
# 197  198  TIGER 단기통안채  100,125      5  ...   1.08       1,596     NaN    NaN
# 198  199        금호타이어    3,780     20  ...   5.25     173,651  -13.08  -6.74
# 199  200         세방전지   76,800  1,400  ...  24.56      84,641   16.23   6.14
#
# [200 rows x 12 columns]

# %% [markdown]
# #### Info
# info() 메소드는 주로 빠진 값 (None 값)과 데이터 타입을 볼 때 유용함.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 12 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   번호      200 non-null    int64
#  1   종목명     200 non-null    object
#  2   현재가     200 non-null    object
#  3   전일비     200 non-null    object
#  4   등락률     200 non-null    object
#  5   액면가     200 non-null    object
#  6   시가총액    200 non-null    object
#  7   상장주식수   200 non-null    object
#  8   외국인비율   200 non-null    float64
#  9   거래량     200 non-null    object
#  10  PER     181 non-null    object
#  11  ROE     175 non-null    float64
# dtypes: float64(2), int64(1), object(9)
# memory usage: 18.9+ KB

# %% [markdown]
# #### Column

# %%
df.columns
# Out:
# Index(['번호', '종목명', '현재가', '전일비', '등락률', '액면가', '시가총액', '상장주식수', '외국인비율',
#        '거래량', 'PER', 'ROE'],
#       dtype='object')

# %% [markdown]
# #### Index

# %%
df.index
# Out:
# RangeIndex(start=0, stop=200, step=1)

# %% [markdown]
# #### 통계값

# %%
df.describe()
# Out:
#                번호       외국인비율         ROE
# count  200.000000  200.000000  175.000000
# mean   100.500000   21.181850    5.630857
# std     57.879185   17.102119   17.481368
# min      1.000000    0.000000 -135.180000
# 25%     50.750000    9.060000    2.635000
# 50%    100.500000   17.540000    7.180000
# 75%    150.250000   29.137500   11.060000
# max    200.000000   83.980000   86.980000

# %% [markdown]
# #### Shape

# %%
df.shape
# Out:
# (200, 12)

# %% [markdown]
# ### 4-1-12 : DataFrame 의 결측값(Null)
# pandas 에서는 결측값을 NaN(Not a Number) 로 표기함.

# %% [markdown]
# #### 결측값 검사

# %%
df.isna()
# Out:
#         번호    종목명    현재가    전일비    등락률  ...  상장주식수  외국인비율    거래량    PER    ROE
# 0    False  False  False  False  False  ...  False  False  False  False  False
# 1    False  False  False  False  False  ...  False  False  False  False  False
# 2    False  False  False  False  False  ...  False  False  False  False  False
# 3    False  False  False  False  False  ...  False  False  False  False   True
# 4    False  False  False  False  False  ...  False  False  False  False  False
# ..     ...    ...    ...    ...    ...  ...    ...    ...    ...    ...    ...
# 195  False  False  False  False  False  ...  False  False  False  False  False
# 196  False  False  False  False  False  ...  False  False  False  False  False
# 197  False  False  False  False  False  ...  False  False  False   True   True
# 198  False  False  False  False  False  ...  False  False  False  False  False
# 199  False  False  False  False  False  ...  False  False  False  False  False
#
# [200 rows x 12 columns]

# %%
df['종목명'].isnull() #isna() 와 isnull()은 같음
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 195    False
# 196    False
# 197    False
# 198    False
# 199    False
# Name: 종목명, Length: 200, dtype: bool

# %%
df['종목명'].notnull()
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 195    True
# 196    True
# 197    True
# 198    True
# 199    True
# Name: 종목명, Length: 200, dtype: bool

# %% [markdown]
# ### 4-1-13 : DataFrame 의 복사
# df를 **새로운 변수(df_new)에 대입**하고, 새로운 변수 df_new에서 값을 바꾼다면, 원래의 DataFrame df의 값은 어떻게 될까? 바뀔까? 바뀌지 않을까?
#
# **원본 데이터를 유지 시키고자 할 때는 copy()를 사용할 것!!!**

# %%
df.head()
# Out:
#    번호     종목명      현재가    전일비  ...  외국인비율         거래량     PER    ROE
# 0   1    삼성전자   81,500    500  ...  54.68  11,918,571   21.22   9.99
# 1   2  SK하이닉스  132,500  1,000  ...  50.03   3,441,826   20.28   9.53
# 2   3   NAVER  379,000  8,000  ...  57.17     522,859   62.16  15.22
# 3   4   삼성전자우   73,300    400  ...  78.11     656,347   19.08    NaN
# 4   5    LG화학  787,000  3,000  ...  44.26     383,416  120.17   2.93
#
# [5 rows x 12 columns]

# %%
df_new = df

# %%
df_new.head()
# Out:
#    번호     종목명      현재가    전일비  ...  외국인비율         거래량     PER    ROE
# 0   1    삼성전자   81,500    500  ...  54.68  11,918,571   21.22   9.99
# 1   2  SK하이닉스  132,500  1,000  ...  50.03   3,441,826   20.28   9.53
# 2   3   NAVER  379,000  8,000  ...  57.17     522,859   62.16  15.22
# 3   4   삼성전자우   73,300    400  ...  78.11     656,347   19.08    NaN
# 4   5    LG화학  787,000  3,000  ...  44.26     383,416  120.17   2.93
#
# [5 rows x 12 columns]

# %%
df_new['현재가'] = 0

# %%
df_new.head()
# Out:
#    번호     종목명  현재가    전일비     등락률  ...      상장주식수  외국인비율         거래량     PER    ROE
# 0   1    삼성전자    0    500   0.62%  ...  5,969,783  54.68  11,918,571   21.22   9.99
# 1   2  SK하이닉스    0  1,000  -0.75%  ...    728,002  50.03   3,441,826   20.28   9.53
# 2   3   NAVER    0  8,000  -2.07%  ...    164,263  57.17     522,859   62.16  15.22
# 3   4   삼성전자우    0    400   0.55%  ...    822,887  78.11     656,347   19.08    NaN
# 4   5    LG화학    0  3,000   0.38%  ...     70,592  44.26     383,416  120.17   2.93
#
# [5 rows x 12 columns]

# %%
df.head()
# Out:
#    번호     종목명  현재가    전일비     등락률  ...      상장주식수  외국인비율         거래량     PER    ROE
# 0   1    삼성전자    0    500   0.62%  ...  5,969,783  54.68  11,918,571   21.22   9.99
# 1   2  SK하이닉스    0  1,000  -0.75%  ...    728,002  50.03   3,441,826   20.28   9.53
# 2   3   NAVER    0  8,000  -2.07%  ...    164,263  57.17     522,859   62.16  15.22
# 3   4   삼성전자우    0    400   0.55%  ...    822,887  78.11     656,347   19.08    NaN
# 4   5    LG화학    0  3,000   0.38%  ...     70,592  44.26     383,416  120.17   2.93
#
# [5 rows x 12 columns]

# %%
hex(id(df))
# Out:
# '0x7f4fc4be6590'

# %%
hex(id(df_new))
# Out:
# '0x7f4fc4be6590'

# %% [markdown]
# ### 4-1-14 : DataFrame 에 Row 추가하기
# Dictionary 형태로 추가할 Row 데이터를 만들고 **append()** 함수를 사용하여 Row 데이터를 추가할 수 있다. 반드시, **ignore_index=True** 옵션을 같이 추가해야 에러가 나지 않는다.

# %%
df.head()
# Out:
#    번호     종목명  현재가    전일비     등락률  ...      상장주식수  외국인비율         거래량     PER    ROE
# 0   1    삼성전자    0    500   0.62%  ...  5,969,783  54.68  11,918,571   21.22   9.99
# 1   2  SK하이닉스    0  1,000  -0.75%  ...    728,002  50.03   3,441,826   20.28   9.53
# 2   3   NAVER    0  8,000  -2.07%  ...    164,263  57.17     522,859   62.16  15.22
# 3   4   삼성전자우    0    400   0.55%  ...    822,887  78.11     656,347   19.08    NaN
# 4   5    LG화학    0  3,000   0.38%  ...     70,592  44.26     383,416  120.17   2.93
#
# [5 rows x 12 columns]

# %%
df.append({'번호':201, '종목명': 'Oompu', '현재가': 10, '전일비': 1, '등락률': 10.0, '액면가': '100', '시가총액': 100000, '상장주식수': 200000, '외국인비율': 12.34, '거래량': 2500, 'PER': 20.01, 'ROE': 13.24})
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-74-311f90be6f9b> in <module>()
# ----> 1 df.append({'번호':201, '종목명': 'Oompu', '현재가': 10, '전일비': 1, '등락률': 10.0, '액면가': '100', '시가총액': 100000, '상장주식수': 200000, '외국인비율': 12.34, '거래량': 2500, 'PER': 20.01, 'ROE': 13.24})
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in append(self, other, ignore_index, verify_integrity, sort)
#    7709             if isinstance(other, dict):
#    7710                 if not ignore_index:
# -> 7711                     raise TypeError("Can only append a dict if ignore_index=True")
#    7712                 other = Series(other)
#    7713             if other.name is None and not ignore_index:
#
# TypeError: Can only append a dict if ignore_index=True

# %%
df = df.append({'번호':201,'종목명': 'Oompu', '현재가': 10, '전일비': 1, '등락률': 10.0, '액면가': '100', '시가총액': 100000, '상장주식수': 200000, '외국인비율': 12.34, '거래량': 2500, 'PER': 20.01, 'ROE': 13.24}, ignore_index=True)

# %%
df.tail()
# Out:
#       번호          종목명  현재가    전일비  ...  외국인비율      거래량     PER    ROE
# 196  197         보령제약    0    550  ...   6.71  383,355   40.47   8.62
# 197  198  TIGER 단기통안채    0      5  ...   1.08    1,596     NaN    NaN
# 198  199        금호타이어    0     20  ...   5.25  173,651  -13.08  -6.74
# 199  200         세방전지    0  1,400  ...  24.56   84,641   16.23   6.14
# 200  201        Oompu   10      1  ...  12.34     2500   20.01  13.24
#
# [5 rows x 12 columns]

# %% [markdown]
# ### 4-1-15 : DataFrame 에 Column 추가하기
# 새로운 column을 만들고 값을 대입해주면, 자동으로 생성한다.

# %%
df.head()
# Out:
#    번호     종목명  현재가    전일비     등락률  ...      상장주식수  외국인비율         거래량     PER    ROE
# 0   1    삼성전자    0    500   0.62%  ...  5,969,783  54.68  11,918,571   21.22   9.99
# 1   2  SK하이닉스    0  1,000  -0.75%  ...    728,002  50.03   3,441,826   20.28   9.53
# 2   3   NAVER    0  8,000  -2.07%  ...    164,263  57.17     522,859   62.16  15.22
# 3   4   삼성전자우    0    400   0.55%  ...    822,887  78.11     656,347   19.08    NaN
# 4   5    LG화학    0  3,000   0.38%  ...     70,592  44.26     383,416  120.17   2.93
#
# [5 rows x 12 columns]

# %%
df['ROA'] = 10.01

# %%
df.head()
# Out:
#    번호     종목명  현재가    전일비     등락률  ...  외국인비율         거래량     PER    ROE    ROA
# 0   1    삼성전자    0    500   0.62%  ...  54.68  11,918,571   21.22   9.99  10.01
# 1   2  SK하이닉스    0  1,000  -0.75%  ...  50.03   3,441,826   20.28   9.53  10.01
# 2   3   NAVER    0  8,000  -2.07%  ...  57.17     522,859   62.16  15.22  10.01
# 3   4   삼성전자우    0    400   0.55%  ...  78.11     656,347   19.08    NaN  10.01
# 4   5    LG화학    0  3,000   0.38%  ...  44.26     383,416  120.17   2.93  10.01
#
# [5 rows x 13 columns]

# %%
df.loc[ df['종목명'] == 'SK하이닉스' , 'ROA'] = 9.99

# %%
df.head()
# Out:
#    번호     종목명  현재가    전일비     등락률  ...  외국인비율         거래량     PER    ROE    ROA
# 0   1    삼성전자    0    500   0.62%  ...  54.68  11,918,571   21.22   9.99  10.01
# 1   2  SK하이닉스    0  1,000  -0.75%  ...  50.03   3,441,826   20.28   9.53   9.99
# 2   3   NAVER    0  8,000  -2.07%  ...  57.17     522,859   62.16  15.22  10.01
# 3   4   삼성전자우    0    400   0.55%  ...  78.11     656,347   19.08    NaN  10.01
# 4   5    LG화학    0  3,000   0.38%  ...  44.26     383,416  120.17   2.93  10.01
#
# [5 rows x 13 columns]

# %% [markdown]
# # Lesson 4-2: Indexing

# %% [markdown]
# ## Indexing = ?

# %% [markdown]
# ### Indexing = 데이터에서 원하는 부분만 뽑아보기

# %% [markdown]
# ![](./assets/images/p4-2-1_pandas_indexing.png)

# %% [markdown]
# * 남자만
# * 30대만
# * 맨 앞의 20줄만
# * 맨 뒤의 100줄만
# * 직업만
# * 3번 user만
# * 나이와 우편번호만
# * 5번 user의 나이만
# * 30대 여자의 직업만
# * 직업이 프로그래머이거나 엔지니어인 40대 남자들의 우편번호만

# %% [markdown]
# ### 맨 앞의 몇 줄만 인덱싱

# %%
users.head()
# Out:
#         gender  age  occupation    zip
# user_id
# 1            F    1          10  48067
# 2            M   56          16  70072
# 3            M   25          15  55117
# 4            M   45           7  02460
# 5            M   25          20  55455

# %%
users.head(10)
# Out:
#         gender  age  occupation    zip
# user_id
# 1            F    1          10  48067
# 2            M   56          16  70072
# 3            M   25          15  55117
# 4            M   45           7  02460
# 5            M   25          20  55455
# 6            F   50           9  55117
# 7            M   35           1  06810
# 8            M   25          12  11413
# 9            M   25          17  61614
# 10           F   35           1  95370

# %% [markdown]
# ### 맨 뒤의 몇 줄만 인덱싱

# %%
users.tail()
# Out:
#         gender  age  occupation    zip
# user_id
# 6036         F   25          15  32603
# 6037         F   45           1  76006
# 6038         F   56           1  14706
# 6039         F   45           0  01060
# 6040         M   25           6  11106

# %%
users.tail(10)
# Out:
#         gender  age  occupation    zip
# user_id
# 6031         F   18           0  45123
# 6032         M   45           7  55108
# 6033         M   50          13  78232
# 6034         M   25          14  94117
# 6035         F   25           1  78734
# 6036         F   25          15  32603
# 6037         F   45           1  76006
# 6038         F   56           1  14706
# 6039         F   45           0  01060
# 6040         M   25           6  11106

# %% [markdown]
# ### 열 하나만 인덱싱

# %%
users['age']
# Out:
# user_id
# 1        1
# 2       56
# 3       25
# 4       45
# 5       25
# 6       50
# 7       35
# 8       25
# 9       25
# 10      35
# 11      25
# 12      25
# 13      45
# 14      35
# 15      25
# 16      35
# 17      50
# 18      18
# 19       1
# 20      25
# 21      18
# 22      18
# 23      35
# 24      25
# 25      18
# 26      25
# 27      25
# 28      25
# 29      35
# 30      35
#         ..
# 6011    35
# 6012    35
# 6013    25
# 6014    45
# 6015    25
# 6016    45
# 6017    35
# 6018    35
# 6019    25
# 6020    50
# 6021    25
# 6022    25
# 6023    25
# 6024    25
# 6025    25
# 6026    35
# 6027    18
# 6028    18
# 6029    25
# 6030    25
# 6031    18
# 6032    45
# 6033    50
# 6034    25
# 6035    25
# 6036    25
# 6037    45
# 6038    56
# 6039    45
# 6040    25
# Name: age, Length: 6040, dtype: int64

# %%
users.age
# Out:
# user_id
# 1        1
# 2       56
# 3       25
# 4       45
# 5       25
# 6       50
# 7       35
# 8       25
# 9       25
# 10      35
# 11      25
# 12      25
# 13      45
# 14      35
# 15      25
# 16      35
# 17      50
# 18      18
# 19       1
# 20      25
# 21      18
# 22      18
# 23      35
# 24      25
# 25      18
# 26      25
# 27      25
# 28      25
# 29      35
# 30      35
#         ..
# 6011    35
# 6012    35
# 6013    25
# 6014    45
# 6015    25
# 6016    45
# 6017    35
# 6018    35
# 6019    25
# 6020    50
# 6021    25
# 6022    25
# 6023    25
# 6024    25
# 6025    25
# 6026    35
# 6027    18
# 6028    18
# 6029    25
# 6030    25
# 6031    18
# 6032    45
# 6033    50
# 6034    25
# 6035    25
# 6036    25
# 6037    45
# 6038    56
# 6039    45
# 6040    25
# Name: age, Length: 6040, dtype: int64

# %% [markdown]
# ### 여러가지 열  인덱싱

# %%
users[['age', 'zip']]
# Out:
#          age    zip
# user_id
# 1          1  48067
# 2         56  70072
# 3         25  55117
# 4         45  02460
# 5         25  55455
# 6         50  55117
# 7         35  06810
# 8         25  11413
# 9         25  61614
# 10        35  95370
# 11        25  04093
# 12        25  32793
# 13        45  93304
# 14        35  60126
# 15        25  22903
# 16        35  20670
# 17        50  95350
# 18        18  95825
# 19         1  48073
# 20        25  55113
# 21        18  99353
# 22        18  53706
# 23        35  90049
# 24        25  10023
# 25        18  01609
# 26        25  23112
# 27        25  19130
# 28        25  14607
# 29        35  33407
# 30        35  19143
# ...      ...    ...
# 6011      35  80538
# 6012      35  02871
# 6013      25  32301
# 6014      45  80634
# 6015      25  80013
# 6016      45  37209
# 6017      35  21117
# 6018      35  48906
# 6019      25  10024
# 6020      50  10023
# 6021      25  08876
# 6022      25  57006
# 6023      25  43213
# ...

# %% [markdown]
# ### "원하는 행"만 혹은
# ### "원하는 행의 원하는 열"만
# ### 과 같이 더 정교한 인덱싱을 하고자 한다면?

# %% [markdown]
# ### .loc[ index ]
#
# #### 혹은
#
# ### .loc[ index, column]

# %% [markdown]
# ### 행 하나만 인덱싱

# %%
users.loc[3]
# Out:
# gender            M
# age              25
# occupation       15
# zip           55117
# Name: 3, dtype: object

# %% [markdown]
# ### 원하는 행의 원하는 열만 인덱싱

# %%
users.loc[3, 'age']
# Out:
# 25

# %% [markdown]
# ### 여러 행의 여러 열 인덱싱

# %%
users.loc[[3, 4, 5],['age', 'zip']]
# Out:
#          age    zip
# user_id
# 3         25  55117
# 4         45  02460
# 5         25  55455

# %% [markdown]
# ### iloc (index location)
#  - loc : Numpy indexing과 다른 룰 사용 users.loc[1:3] ==> 1, 2, 3 모두 포함
#  - iloc : Numpy indexing과 같은 룰 사용 users.iloc[1:3] ==> 1, 2 만 포함하고 3은 포함하지 않음.

# %%
users.iloc[1:3,2:4]

# %% [markdown]
# ### 조건에 맞는 데이터만 인덱싱 = Filtering
# * 남자/여자만
# * 20대만
# * ...

# %%
users[lambda x: x.gender == 'F']
# Out:
#         gender  age  occupation         zip
# user_id
# 1            F    1          10       48067
# 6            F   50           9       55117
# 10           F   35           1       95370
# 11           F   25           1       04093
# 16           F   35           0       20670
# 18           F   18           3       95825
# 24           F   25           7       10023
# 28           F   25           1       14607
# 30           F   35           7       19143
# 32           F   25           0       19355
# 34           F   18           0       02135
# 37           F   25           9       66212
# 38           F   18           4       02215
# 41           F   18           4       15116
# 45           F   45          16       94110
# 50           F   25           2       98133
# 51           F    1          10       10562
# 55           F   35          12       55303
# 59           F   50           1       55413
# 62           F   35           3       98105
# ...

# %% [markdown]
# ### Filtering 자세히 보기

# %% [markdown]
# #### 1st 주어진 데이터 : users

# %%
users
# Out:
#         gender  age  occupation    zip
# user_id
# 1            F    1          10  48067
# 2            M   56          16  70072
# 3            M   25          15  55117
# 4            M   45           7  02460
# 5            M   25          20  55455
# 6            F   50           9  55117
# 7            M   35           1  06810
# 8            M   25          12  11413
# 9            M   25          17  61614
# 10           F   35           1  95370
# 11           F   25           1  04093
# 12           M   25          12  32793
# 13           M   45           1  93304
# 14           M   35           0  60126
# 15           M   25           7  22903
# 16           F   35           0  20670
# 17           M   50           1  95350
# 18           F   18           3  95825
# 19           M    1          10  48073
# 20           M   25          14  55113
# 21           M   18          16  99353
# 22           M   18          15  53706
# 23           M   35           0  90049
# ...

# %% [markdown]
# #### 2nd 열 하나 : users.gender

# %%
users.gender
# Out:
# user_id
# 1       F
# 2       M
# 3       M
# 4       M
# 5       M
# 6       F
# 7       M
# 8       M
# 9       M
# 10      F
# 11      F
# 12      M
# 13      M
# 14      M
# 15      M
# 16      F
# 17      M
# 18      F
# 19      M
# 20      M
# 21      M
# 22      M
# 23      M
# 24      F
# 25      M
# 26      M
# 27      M
# 28      F
# 29      M
# 30      F
#        ..
# 6011    M
# 6012    M
# 6013    F
# 6014    M
# 6015    F
# 6016    M
# 6017    F
# 6018    M
# 6019    M
# 6020    M
# 6021    M
# 6022    M
# 6023    M
# 6024    M
# 6025    F
# 6026    M
# 6027    M
# 6028    M
# 6029    F
# 6030    M
# 6031    F
# 6032    M
# 6033    M
# 6034    M
# 6035    F
# 6036    F
# 6037    F
# 6038    F
# 6039    F
# 6040    M
# Name: gender, Length: 6040, dtype: object

# %% [markdown]
# #### 3rd True|False : users.gender == 'F'

# %%
users.gender == 'F'
# Out:
# user_id
# 1        True
# 2       False
# 3       False
# 4       False
# 5       False
# 6        True
# 7       False
# 8       False
# 9       False
# 10       True
# 11       True
# 12      False
# 13      False
# 14      False
# 15      False
# 16       True
# 17      False
# 18       True
# 19      False
# 20      False
# 21      False
# 22      False
# 23      False
# 24       True
# 25      False
# 26      False
# 27      False
# 28       True
# 29      False
# 30       True
#         ...
# 6011    False
# 6012    False
# 6013     True
# 6014    False
# 6015     True
# 6016    False
# 6017     True
# 6018    False
# 6019    False
# 6020    False
# 6021    False
# 6022    False
# 6023    False
# 6024    False
# 6025     True
# 6026    False
# 6027    False
# 6028    False
# 6029     True
# 6030    False
# 6031     True
# 6032    False
# 6033    False
# 6034    False
# 6035     True
# 6036     True
# 6037     True
# 6038     True
# 6039     True
# 6040    False
# ...

# %% [markdown]
# #### 4th True 행만 남음 :  users[users.gender == 'F']

# %%
users[users.gender == 'F']
# Out:
#         gender  age  occupation         zip
# user_id
# 1            F    1          10       48067
# 6            F   50           9       55117
# 10           F   35           1       95370
# 11           F   25           1       04093
# 16           F   35           0       20670
# 18           F   18           3       95825
# 24           F   25           7       10023
# 28           F   25           1       14607
# 30           F   35           7       19143
# 32           F   25           0       19355
# 34           F   18           0       02135
# 37           F   25           9       66212
# 38           F   18           4       02215
# 41           F   18           4       15116
# 45           F   45          16       94110
# 50           F   25           2       98133
# 51           F    1          10       10562
# 55           F   35          12       55303
# 59           F   50           1       55413
# 62           F   35           3       98105
# ...

# %% [markdown]
# ### lambda 를 쓰는 이유 = ?

# %% [markdown]
# ### DataFrame 이름을 다시 쓰기 귀찮기 때문...
# - lambda를 쓰지 않는 경우 : users[<font color='red'>**users**</font>.gender == 'F']
# - lambda를 쓰는 경우 : users[<font color='red'>**lambda**</font> x: x.gender == 'F']

# %% [markdown]
# ### A이거나 B일 조건 인덱싱

# %%
users[lambda x: x.occupation.isin([12, 17])]
# Out:
#         gender  age  occupation     zip
# user_id
# 8            M   25          12   11413
# 9            M   25          17   61614
# 12           M   25          12   32793
# 43           M   25          12   60614
# 44           M   45          17   98052
# 49           M   18          12   77084
# 55           F   35          12   55303
# 61           M   25          17   95122
# 65           M   35          12   55803
# 82           M   25          17   48380
# 93           M   25          17   95825
# 94           M   25          17   28601
# 100          M   35          17   95401
# 104          M   25          12   00926
# 105          M   45          12   90277
# 108          M   25          12   30316
# 113          M   18          12   37032
# 115          M   25          17   28083
# 116          M   25          17   55744
# 117          M   25          17   33314
# 118          M   35          17   22315
# 130          M   35          17   50021
# ...

# %% [markdown]
# # Lesson 4-3: Groupby

# %% [markdown]
# ## Groupby = ?

# %% [markdown]
# ### Groupby = 그룹 별로 비교해보기

# %% [markdown]
# ![](https://github.com/ttc-edu-dev-team/da-structured-data/blob/main/assets/images/p4-3-1_pandas_groupby.png?raw=true)

# %% [markdown]
# * 성별 별로
# * 직업 별로
# * 나이대 별로
# * ...

# %% [markdown]
# ### Split - Apply - Combine 하기
#
# ![](https://github.com/ttc-edu-dev-team/da-structured-data/blob/main/assets/images/p4-3-2_pandas_groupby_split-apply-combine.png?raw=true)

# %%
users.groupby('gender')['age'].mean()
# Out:
# gender
# F    30.859567
# M    30.552297
# Name: age, dtype: float64

# %% [markdown]
# ## .groupby(<font color='green'>key</font>)[<font color='blue'>column</font>].<font color='purple'>operation</font>()

# %% [markdown]
# ### 같은 <font color='green'>key</font>를 가진 데이터끼리 묶어서
# ### 그룹마다 <font color='blue'>column</font>을 인덱싱해서(뽑아내서)
# ### <font color='purple'>operation</font>을 적용하여 계산한 뒤
# ### 각 그룹의 결과를 합쳐서 하나의 DataFrame으로 만든다.

# %% [markdown]
# ### groupby 자세히 보기

# %% [markdown]
# #### 1st : age열을 gender로 그룹핑

# %%
grouped = users['age'].groupby(users.gender)
grouped

# %% [markdown]
# #### 2nd : Split된 상태로 GroupBy object가 리턴되는데...안을 들여다 볼수는 없다.

# %% [markdown]
# #### 3rd : 함수를 적용하면 그룹들의 결과를 합쳐서 보여준다.

# %%
grouped.mean()
# Out:
# gender
# F    30.859567
# M    30.552297
# Name: age, dtype: float64

# %% [markdown]
# ## 1번 방법 : users[<font color='blue'>age</font>].groupby(<font color='green'>users.gender</font>).<font color='purple'>mean</font>()
#
# ## 2번 방법 : users.groupby(<font color='green'>gender</font>)[<font color='blue'>age</font>].<font color='purple'>mean</font>()

# %% [markdown]
# ## 1번 방법이...변수 반복 등 귀찮아서...2번 방법이 나오게 됨.

# %% [markdown]
# ### groupby 결과를 DataFrame으로 보기

# %%
users.groupby('gender')[['age']].mean()
# Out:
#               age
# gender
# F       30.859567
# M       30.552297

# %% [markdown]
# ## .groupby(key)<font color='red'>[[</font>column<font color='red'>]]</font>.operation()

# %% [markdown]
# ## groupby와 함께 쓰이는 함수들
# - 갯수 .size()
# - 합 .sum()
# - 평균 .mean()
# - 중앙값 .median()
# - 표준편차 .std()
# - 최대값 .max()
# - 최소값 .min()
# - 내가 만든 함수 .apply(내가 만든 함수명)

# %% [markdown]
# ### Multiple Indexing

# %% [markdown]
# #### Multiple Index 적용 방법
# 행 Index를 Multiple로 구성하고 싶은 경우, 행 Index를 리스트로 만들어 준다.

# %%
users.groupby(['gender', 'occupation']).mean()

# %% [markdown]
# #### Multiple Index가 적용된  데이터 프레임을 피벗 테이블로 변환 방법

# %%
users_pivoted = users.groupby(['gender', 'occupation']).mean()
users_pivoted

# %%
users_pivoted.unstack('gender')

# %%
users_pivoted.unstack('occupation')

# %% [markdown]
# #### Reset Index 적용하기

# %%
users_pivoted

# %%
users_reset_index = users_pivoted.reset_index()

# %%
users_reset_index

# %% [markdown]
# # Lesson 4-4: Assign

# %% [markdown]
# ## Assign = ?

# %% [markdown]
# ### Assign = column 추가하기

# %% [markdown]
# ## 첫번째 방법 : ['new_column'] = column

# %%
unames = ['user_id', 'gender', 'age', 'occupation', 'zip'] 
users1 = pd.read_table('./data/pandas/users.dat', sep='::', header=None, names=unames, engine='python', index_col='user_id')
# Out:
# /Users/parksurk/anaconda3/envs/kaggle/lib/python3.6/site-packages/ipykernel_launcher.py:2: FutureWarning: read_table is deprecated, use read_csv instead.

# %%
users1['age_range'] = users1['age'] // 10 * 10
users1
# Out:
#         gender  age  occupation    zip  age_range
# user_id
# 1            F    1          10  48067          0
# 2            M   56          16  70072         50
# 3            M   25          15  55117         20
# 4            M   45           7  02460         40
# 5            M   25          20  55455         20
# 6            F   50           9  55117         50
# 7            M   35           1  06810         30
# 8            M   25          12  11413         20
# 9            M   25          17  61614         20
# 10           F   35           1  95370         30
# 11           F   25           1  04093         20
# 12           M   25          12  32793         20
# 13           M   45           1  93304         40
# 14           M   35           0  60126         30
# 15           M   25           7  22903         20
# 16           F   35           0  20670         30
# 17           M   50           1  95350         50
# 18           F   18           3  95825         10
# ...

# %% [markdown]
# ## 두번째 방법 : .assign(new_column = column)

# %%
unames = ['user_id', 'gender', 'age', 'occupation', 'zip'] 
users2 = pd.read_table('./data/pandas/users.dat', sep='::', header=None, names=unames, engine='python', index_col='user_id')
# Out:
# /Users/parksurk/anaconda3/envs/kaggle/lib/python3.6/site-packages/ipykernel_launcher.py:2: FutureWarning: read_table is deprecated, use read_csv instead.

# %%
users2.assign(age_range = lambda x: x.age //10 * 10)
# Out:
#         gender  age  occupation    zip  age_range
# user_id
# 1            F    1          10  48067          0
# 2            M   56          16  70072         50
# 3            M   25          15  55117         20
# 4            M   45           7  02460         40
# 5            M   25          20  55455         20
# 6            F   50           9  55117         50
# 7            M   35           1  06810         30
# 8            M   25          12  11413         20
# 9            M   25          17  61614         20
# 10           F   35           1  95370         30
# 11           F   25           1  04093         20
# 12           M   25          12  32793         20
# 13           M   45           1  93304         40
# 14           M   35           0  60126         30
# 15           M   25           7  22903         20
# 16           F   35           0  20670         30
# 17           M   50           1  95350         50
# 18           F   18           3  95825         10
# ...

# %% [markdown]
# ## 첫번째 방법  vs. 두번째 방법
#
# ## - 첫번째 방법 : ['new_column'] = column : <font color='red'>원본 데이터 바뀜</font>
# ## - 두번째 방법 : .assign(new_column = column) : <font color='red'>원본 데이터 바뀌지 않음 = 좋은 방법</font>

# %%
users2_added = users2.assign(age_range = lambda x: x.age //10 * 10)

# %%
users2
# Out:
#         gender  age  occupation    zip
# user_id
# 1            F    1          10  48067
# 2            M   56          16  70072
# 3            M   25          15  55117
# 4            M   45           7  02460
# 5            M   25          20  55455
# 6            F   50           9  55117
# 7            M   35           1  06810
# 8            M   25          12  11413
# 9            M   25          17  61614
# 10           F   35           1  95370
# 11           F   25           1  04093
# 12           M   25          12  32793
# 13           M   45           1  93304
# 14           M   35           0  60126
# 15           M   25           7  22903
# 16           F   35           0  20670
# 17           M   50           1  95350
# 18           F   18           3  95825
# 19           M    1          10  48073
# 20           M   25          14  55113
# 21           M   18          16  99353
# 22           M   18          15  53706
# 23           M   35           0  90049
# ...

# %% [markdown]
# # Lesson 4-5: Method Chaining

# %% [markdown]
# ## Method Chaining = ?

# %% [markdown]
# ## Method Chaining = Pandas의 각 기능들을 잘 조합하는 방법

# %% [markdown]
# ## Pandas 의 수많은 기능들
#
# - 데이터 불러오기
# - 정렬하기
# - 결측값 제거하기
# - 중복값 제거하기
# - 컬럼 이름 바꾸기
# - DataFrame끼리 사칙연산 하기
# - 다른 데이터와 합치기
# - ...

# %% [markdown]
# ## 데이터 분석은 작은 method들의 연속

# %% [markdown]
# * a = 데이터에서 원하는 부분 인덱싱
# * b = a 와 다른 데이터와 합침
# * c = b에서 열 이름 바꿈
# * d = c에서 새로운 열 추가함
# * e = d를 정렬함
# * ...
# * z = 최종 내가 원하는 DataFrame

# %% [markdown]
# ## 문제점
# 1. 새로운 변수 이름을 생각해 내기 힘들다.
# 2. 이름만 보고 무슨 변수인지 예측하기 어렵다.
# 3. 나중에 쓰이지 않을 변수가 너무 많다.

# %% [markdown]
# ## 해결방법 = Method Chaining

# %% [markdown]
# ### [Before]
# #### a = data.this_method()
# #### b = a.that_method()
# #### c = b.another_method()

# %% [markdown]
# ### [After]
# #### data_new = <font color='red'>(</font> data.this_method()
# ####                 .that_method()
# ####                 .another_method()
# ####            <font color='red'>)</font>

# %% [markdown]
# ### 전체를 <font color='red'>소괄호</font>로 묶어야 함.

# %% [markdown]
# ## Method Chaining 예 : 직업 별로 연령대 비중 구하기

# %%
age_to_range = { 1: "Under 18", 18: "18-24", 25: "25-34", 35: "35-44", 45: "45-49", 50: "50-55", 56: "56+" }
to_description = { 0: "other or not specified", 1: "academic/educator", 2: "artist", 3: "clerical/admin",
                4: "college/grad student", 5: "customer service", 6: "doctor/health care",
                7: "executive/managerial", 8: "farmer", 9: "homemaker", 10: "K-12 student", 11: "lawyer",
                12: "programmer", 13: "retired", 14: "sales/marketing", 15: "scientist", 16: "self-employed",
                17: "technician/engineer", 18: "tradesman/craftsman", 19: "unemployed", 20: "writer" }
(users
 .assign(age_range = lambda x: x.age.map(age_to_range))
 .assign(occupation = lambda x: x.occupation.map(to_description))
 .groupby(['occupation', 'age_range']).size()
 .unstack()
 .fillna(0)
 .pipe(lambda x: x.div(x.sum(axis='columns'), axis='index'))
 .mul(100)
 .round(2)
)
# Out:
# age_range               18-24  25-34  35-44  45-49  50-55    56+  Under 18
# occupation
# K-12 student            14.87   0.51   0.51   0.00   0.00   0.51     83.59
# academic/educator        8.52  29.55  22.35  15.15  13.26  10.42      0.76
# artist                  16.48  42.32  17.60  11.24   6.74   4.49      1.12
# clerical/admin          10.40  39.31  24.28   9.83   9.25   6.94      0.00
# college/grad student    70.36  26.35   1.84   0.40   0.66   0.00      0.40
# customer service        16.07  46.43  22.32   8.93   5.36   0.89      0.00
# doctor/health care       3.81  32.20  25.00  13.14  16.95   8.90      0.00
# executive/managerial     2.50  37.26  31.52  10.90  11.78   5.74      0.29
# farmer                   5.88  35.29  17.65   5.88  11.76  17.65      5.88
# homemaker                6.52  31.52  38.04  11.96   7.61   4.35      0.00
# lawyer                   5.43  39.53  24.03  13.18  12.40   4.65      0.78
# ...

# %% [markdown]
# # Lesson 4-6 Pandas 전처리 메소드

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
#filename = '/content/drive/My Drive/da-structured-data/data/titanic/test.csv'
filename = './data/titanic/test.csv'

# %%
df = pd.read_csv(filename)

# %%
df
# Out:
#      PassengerId  Pclass                                               Name  \
# 0            892       3                                   Kelly, Mr. James
# 1            893       3                   Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                          Myles, Mr. Thomas Francis
# 3            895       3                                   Wirz, Mr. Albert
# 4            896       3       Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# 5            897       3                         Svensson, Mr. Johan Cervin
# 6            898       3                               Connolly, Miss. Kate
# 7            899       2                       Caldwell, Mr. Albert Francis
# 8            900       3          Abrahim, Mrs. Joseph (Sophie Halaut Easu)
# 9            901       3                            Davies, Mr. John Samuel
# 10           902       3                                   Ilieff, Mr. Ylio
# ...

# %% [markdown]
# ## 4-6-1 : fillna
# 결측치(NaN)를 채워주는 메소드

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
# PassengerId    418 non-null int64
# Pclass         418 non-null int64
# Name           418 non-null object
# Sex            418 non-null object
# Age            332 non-null float64
# SibSp          418 non-null int64
# Parch          418 non-null int64
# Ticket         418 non-null object
# Fare           417 non-null float64
# Cabin          91 non-null object
# Embarked       418 non-null object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 36.0+ KB

# %%
df['Age']
# Out:
# 0      34.5
# 1      47.0
# 2      62.0
# 3      27.0
# 4      22.0
# 5      14.0
# 6      30.0
# 7      26.0
# 8      18.0
# 9      21.0
# 10      NaN
# 11     46.0
# 12     23.0
# 13     63.0
# 14     47.0
# 15     24.0
# 16     35.0
# 17     21.0
# 18     27.0
# 19     45.0
# 20     55.0
# 21      9.0
# 22      NaN
# 23     21.0
# 24     48.0
# 25     50.0
# 26     22.0
# 27     22.5
# 28     41.0
# 29      NaN
#        ...
# 388    21.0
# 389     6.0
# 390    23.0
# 391    51.0
# 392    13.0
# 393    47.0
# 394    29.0
# 395    18.0
# 396    24.0
# 397    48.0
# 398    22.0
# 399    31.0
# 400    30.0
# 401    38.0
# 402    22.0
# 403    17.0
# 404    43.0
# 405    20.0
# 406    23.0
# 407    50.0
# 408     NaN
# 409     3.0
# 410     NaN
# 411    37.0
# 412    28.0
# 413     NaN
# 414    39.0
# 415    38.5
# 416     NaN
# 417     NaN
# Name: Age, Length: 418, dtype: float64

# %%
df['Age'].fillna(0)
# Out:
# 0      34.5
# 1      47.0
# 2      62.0
# 3      27.0
# 4      22.0
# 5      14.0
# 6      30.0
# 7      26.0
# 8      18.0
# 9      21.0
# 10      0.0
# 11     46.0
# 12     23.0
# 13     63.0
# 14     47.0
# 15     24.0
# 16     35.0
# 17     21.0
# 18     27.0
# 19     45.0
# 20     55.0
# 21      9.0
# 22      0.0
# 23     21.0
# 24     48.0
# 25     50.0
# 26     22.0
# 27     22.5
# 28     41.0
# 29      0.0
#        ...
# 388    21.0
# 389     6.0
# 390    23.0
# 391    51.0
# 392    13.0
# 393    47.0
# 394    29.0
# 395    18.0
# 396    24.0
# 397    48.0
# 398    22.0
# 399    31.0
# 400    30.0
# 401    38.0
# 402    22.0
# 403    17.0
# 404    43.0
# 405    20.0
# 406    23.0
# 407    50.0
# 408     0.0
# 409     3.0
# 410     0.0
# 411    37.0
# 412    28.0
# 413     0.0
# 414    39.0
# 415    38.5
# 416     0.0
# 417     0.0
# Name: Age, Length: 418, dtype: float64

# %%
df
# Out:
#      PassengerId  Pclass                                               Name  \
# 0            892       3                                   Kelly, Mr. James
# 1            893       3                   Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                          Myles, Mr. Thomas Francis
# 3            895       3                                   Wirz, Mr. Albert
# 4            896       3       Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# 5            897       3                         Svensson, Mr. Johan Cervin
# 6            898       3                               Connolly, Miss. Kate
# 7            899       2                       Caldwell, Mr. Albert Francis
# 8            900       3          Abrahim, Mrs. Joseph (Sophie Halaut Easu)
# 9            901       3                            Davies, Mr. John Samuel
# 10           902       3                                   Ilieff, Mr. Ylio
# ...

# %% [markdown]
# df에 결측치 변경사항을 반영하려면 **inplace=True** 옵션을 주거나,

# %%
df2 = df.copy()

# %%
df2['Age']

# %%
df2['Age'].fillna(0, inplace=True)

# %%
df2['Age']

# %% [markdown]
# fillna() 로 **채워 준 값을 다시 대입**해 주어야 한다.

# %%
df3 = df.copy()

# %%
df3['Age']

# %%
df3['Age'] = df3['Age'].fillna(0)

# %%
df3['Age']

# %% [markdown]
# ## 4-6-2 : dropna
# 결측치(NaN)가 있는 행을 제거하는 메소드

# %%
df4 = df.copy()

# %%
df4.info()

# %%
df4

# %%
df4.dropna()

# %%
df4

# %% [markdown]
# ### axis 옵션
# - axis=0은 행을 제거한다.
# - axis=1은 열을 제거한다.

# %%
df4.dropna(axis=0)

# %%
df4.dropna(axis=1)

# %% [markdown]
# ### how 옵션
# - 'any' : 한개라도 NaN이 있는 경우 제거한다.
# - 'all' : 모두 NaN인 경우 제거한다.

# %%
df5 = df.copy()

# %%
df5.dropna()

# %%
df5.dropna(axis=0, how='any')

# %%
df5.dropna(axis=0, how='all')

# %%
df5.iloc[10] = np.nan

# %%
df5

# %%
df5.dropna(axis=0, how='all')

# %% [markdown]
# ## 4-6-3 : drop_duplicates
# 중복된 값 제거하는 메소드

# %%
df6 = df.copy()

# %%
df6['Age']

# %%
df6['Age'].drop_duplicates

# %% [markdown]
# ### keep 옵션
# - 'first' : 첫번째에 나오는 데이터를 유지.(default)
# - 'last' : 마지막에 나오는 데이터를 유지.

# %%
df7 = df.copy()

# %%
df7['Age']

# %%
df7['Age'].drop_duplicates(keep='last')

# %% [markdown]
# ### 행 전체 제거

# %%
df8 = df.copy()

# %%
df8.drop_duplicates('Age')

# %% [markdown]
# ## 4-6-4 : drop
# column, row 제거하는 메소드

# %% [markdown]
# ### column 제거하는 방법
# axis=1 옵션을 사용한다.

# %%
df9 = df.copy()

# %%
df9.head()

# %%
df9.drop('Age', axis=1)

# %%
df9.drop(['Age', 'Occupation'], axis=1)

# %% [markdown]
# ### row 제거하는 방법
# axis=0 옵션을 사용한다.

# %%
df10 = df.copy()

# %%
df10.head()

# %%
df10.drop(3, axis=0)

# %%
df10.drop([2,4], axis=0)

# %% [markdown]
# ## 4-6-5 : concat
# DataFrame 합치기

# %% [markdown]
# ### Row 기준으로 합치기

# %%
#filename = '/content/drive/My Drive/da-structured-data/data/titanic/test.csv'
filename = './data/titanic/test.csv'

# %%
df11 = pd.read_csv(filename)
df11.head()

# %%
#filename2 = '/content/drive/My Drive/da-structured-data/data/titanic/train.csv'
filename2 = './data/titanic/train.csv'

# %%
df12 = pd.read_csv(filename2)
df12.head()

# %% [markdown]
# #### sort 옵션
# row 기준으로 합칠 때는 pd.concat에 합칠 데이터프레임을 list 형태로 나열합니다. row 기준으로 합칠 때는 ***sort=False*** 옵션을 주면 기존 순서가 유지된다.

# %%
pd.concat([df11, df12], sort=False)

# %% [markdown]
# #### reset_index() 로 인덱스 재설정
# concat 이후에 인덱스가 맞지 않으므로 reset_index()로 인덱스를 초기화하여 재설정한다.

# %%
df_concat = pd.concat([df11, df12], sort=False)
df_concat

# %%
df_concat.reset_index()

# %% [markdown]
# reset_index() 호출 후 index 라는 column이 추가되므로 ***drop=True*** 옵션으로 index column이 생기지 않도록 한다.

# %%
df_concat.reset_index(drop=True)

# %% [markdown]
# ### Column 기준으로 합치기
# column을 기준으로 합칠 때는 **axis=1 옵션**을 사용한다.

# %%
pd.concat([df11, df12], axis=1)

# %% [markdown]
# #### 행의 갯수가 맞지 않는 상태에서 column 기준으로 합치는 경우
# 비어 있는 셀이 NaN으로 채워진다.

# %%
df13 = df12.drop([3, 5])

# %%
pd.concat([df12, df13], axis=1)

# %%
df13

# %% [markdown]
# ## 4-6-5 : merge
# DataFrame 병합하기
#
# * concat : row나 column 기준으로 단순하게 이어 붙히기
# * merge : 특정 고유한 키(unique id) 값을 기준으로 병합하기

# %%
df14 = pd.read_csv(filename)
df14.head()

# %%
df15 = df14.copy()
df15.drop(['Pclass','Name','Sex','Age'], axis=1)
df15.head()

# %%
df14.drop(['SibSp','Parch','Ticket','Fare','Cabin','Embarked'], axis=1)
df14.head()

# %% [markdown]
# df14와 df15는 **'PassengerId' 이라는 column이 모두 존재**한다.
#
# 따라서 'PassengerId'을 기준으로 두 DataFrame을 **Merge**할 수 있다.

# %% [markdown]
# **pd.merge(left, right, on='Merge의 기준이 되는 column', how='left')**
#
# * left와 right에는 Merge할 두개의 DataFrame을 각각 설정한다.
# * on 옵션 : Merge의 기준이 되는 column을 설정한다.
# * how 옵션 : 'left', 'right', 'inner', 'outer' 라는 4가지의 Merge 방식중 한가지를 선택한다.

# %% [markdown]
# ### left, right 옵션 사용 예

# %%
df15.head()

# %%
df_right = df15.drop([1, 2, 3, 4, 5], axis=0)

# %%
df_right = df_right.reset_index(drop=True)

# %%
df_right.head()

# %%
df_left = df14.copy()

# %%
pd.concat([df_left, df_right], axis=1)

# %% [markdown]
# #### concat을 사용해서 합쳤을 때는 제대로 합쳐지지 않는다

# %%
pd.merge(df_left, df_right, on='PassengerId', how='left')

# %% [markdown]
# #### 'left' 옵션일 경우, left DataFrame에 키 값이 존재하면 해당 데이터를 유지하고, Merge한 right DataFrame의 값은 NaN이 된다.

# %%
pd.merge(df_left, df_right, on='PassengerId', how='right')

# %% [markdown]
# #### 'right' 옵션일 경우, right DataFrame을 기준으로 Merge하게 된다.
#
# 이 예에서는 left DataFrame이 더 많은 데이터를 갖고 있기 때문에, right를 기준으로 Merge한 결과 DataFrame의 행 크기가 줄어든다.

# %% [markdown]
# ### Inner, Outer 옵션 사용 예
# * inner 옵션 : 두 DataFrame 모두 Key가 존재하는 경우만 Merge한다.
# * outer 옵션 : 하나의 DataFrame에 Key가 존재하는 경우 모두 Merge한다.
# * outer 옵션 선택시, 없는 값은 NaN이 된다.

# %%
pd.merge(df_left, df_right, on='PassengerId', how='inner')

# %%
pd.merge(df_left, df_right, on='PassengerId', how='outer')

# %% [markdown]
# ## 4-6-6 : Series type 변환하기

# %% [markdown]
# ### type 확인하기

# %%
df16 = pd.read_csv(filename)

# %%
df16.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
# PassengerId    418 non-null int64
# Pclass         418 non-null int64
# Name           418 non-null object
# Sex            418 non-null object
# Age            332 non-null float64
# SibSp          418 non-null int64
# Parch          418 non-null int64
# Ticket         418 non-null object
# Fare           417 non-null float64
# Cabin          91 non-null object
# Embarked       418 non-null object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 36.0+ KB

# %% [markdown]
# * object: 일반 문자열 타입
# * float: 실수
# * int: 정수
# * category: 카테고리형 변수
# * datetime: 시간형 변수

# %% [markdown]
# ### type 변환하기
# type 변환은 **astype** 메소드를 사용한다.

# %%
df16['Age'].dtypes
# Out:
# dtype('float64')

# %%
df16['Age'].astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-30-c5c33c25237a> in <module>
# ----> 1 df16['Age'].astype(int)
#
# ~/anaconda3/envs/kaggle/lib/python3.6/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors, **kwargs)
#    5689             # else, only a single dtype is given
#    5690             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors,
# -> 5691                                          **kwargs)
#    5692             return self._constructor(new_data).__finalize__(self)
#    5693
#
# ~/anaconda3/envs/kaggle/lib/python3.6/site-packages/pandas/core/internals/managers.py in astype(self, dtype, **kwargs)
#     529
#     530     def astype(self, dtype, **kwargs):
# --> 531         return self.apply('astype', dtype=dtype, **kwargs)
#     532
#     533     def convert(self, **kwargs):
#
# ...

# %%
df16['Age'] = df16['Age'].fillna(df16['Age'].mean())
df16['Age'].astype(int)
# Out:
# 0      34
# 1      47
# 2      62
# 3      27
# 4      22
# 5      14
# 6      30
# 7      26
# 8      18
# 9      21
# 10     30
# 11     46
# 12     23
# 13     63
# 14     47
# 15     24
# 16     35
# 17     21
# 18     27
# 19     45
# 20     55
# 21      9
# 22     30
# 23     21
# 24     48
# 25     50
# 26     22
# 27     22
# 28     41
# 29     30
#        ..
# 388    21
# 389     6
# 390    23
# 391    51
# 392    13
# 393    47
# 394    29
# 395    18
# 396    24
# 397    48
# 398    22
# 399    31
# 400    30
# 401    38
# 402    22
# 403    17
# 404    43
# 405    20
# 406    23
# 407    50
# 408    30
# 409     3
# 410    30
# 411    37
# 412    28
# 413    30
# 414    39
# 415    38
# 416    30
# 417    30
# Name: Age, Length: 418, dtype: int64

# %% [markdown]
# ## 4-6-7 : apply
# Series나 DataFrame에 **사용자정의 함수** 적용하고 싶은 경우 사용한다.
#
# * apply를 사용하기 위해서는 사용자정의 함수가 먼저 정의되어야 한다.
# * apply는 사용자정의 함수를 인자로 넘겨준다.

# %%
df16.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
# PassengerId    418 non-null int64
# Pclass         418 non-null int64
# Name           418 non-null object
# Sex            418 non-null object
# Age            418 non-null float64
# SibSp          418 non-null int64
# Parch          418 non-null int64
# Ticket         418 non-null object
# Fare           417 non-null float64
# Cabin          91 non-null object
# Embarked       418 non-null object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 36.0+ KB

# %%
df16.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %% [markdown]
# ### Series 에 apply 사용하는 경우

# %%
def user_define_sex(x):
    if x == 'female':
        return 0
    elif x == 'male':
        return 1
    else:
        return -1

# %%
df16['Sex_new'] = df16['Sex'].apply(user_define_sex)

# %%
df16.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked  Sex_new
# 0  34.5      0      0   330911   7.8292   NaN        Q        1
# 1  47.0      1      0   363272   7.0000   NaN        S        0
# 2  62.0      0      0   240276   9.6875   NaN        Q        1
# 3  27.0      0      0   315154   8.6625   NaN        S        1
# 4  22.0      1      1  3101298  12.2875   NaN        S        0

# %% [markdown]
# ### DataFrame 에 apply 사용하는 경우

# %%
def user_define_fuction(df):
    value = df['Fare'] / df['Age']
    return value

# %%
df16.apply(user_define_fuction, axis=1)
# Out:
# 0      0.226933
# 1      0.148936
# 2      0.156250
# 3      0.320833
# 4      0.558523
# 5      0.658929
# 6      0.254307
# 7      1.115385
# 8      0.401622
# 9      1.150000
# 10     0.260823
# 11     0.565217
# 12     3.576813
# 13     0.412698
# 14     1.301596
# 15     1.155033
# 16     0.352857
# 17     0.344048
# 18     0.293519
# 19     0.160556
# 20     1.080000
# 21     0.352311
# 22     1.046600
# 23     2.922819
# 24     5.466146
# 25     0.290000
# 26     2.817236
# 27     0.321111
# 28     0.743902
# 29     0.716133
#          ...
# 388    0.369048
# 389    3.512500
# 390    4.065217
# 391    0.772549
# 392    1.557692
# 393    0.223404
# 394    0.759483
# 395    3.333333
# 396    0.302083
# 397    1.650000
# 398    0.353409
# 399    0.249461
# 400    5.495557
# 401    0.552632
# 402    2.700000
# 403    2.770588
# 404    0.644670
# 405    0.693125
# 406    0.456522
# 407    4.230000
# 408    0.255043
# 409    4.591667
# 410    0.256007
# 411    2.432432
# ...

# %% [markdown]
# ### apply에 lambda 사용하는 경우
#
# * lambda는 1줄로 작성하는 간단 함수식이다.
# * lambda는 return을 별도로 명기하지 않는 특징이 있다.
# * **복잡한 조건식은 사용자정의 함수**를 사용하고, **간단한 계산식은 lambda**를 사용한다.

# %%
f = lambda x: 0 if x == 'female' else 1

# %%
df16['Sex'].apply(f)
# Out:
# 0      1
# 1      0
# 2      1
# 3      1
# 4      0
# 5      1
# 6      0
# 7      1
# 8      0
# 9      1
# 10     1
# 11     1
# 12     0
# 13     1
# 14     0
# 15     0
# 16     1
# 17     1
# 18     0
# 19     0
# 20     1
# 21     1
# 22     0
# 23     1
# 24     0
# 25     1
# 26     0
# 27     1
# 28     1
# 29     1
#       ..
# 388    1
# 389    1
# 390    1
# 391    0
# 392    1
# 393    1
# 394    1
# 395    0
# 396    1
# 397    0
# 398    1
# 399    1
# 400    0
# 401    1
# 402    0
# 403    1
# 404    1
# 405    1
# 406    1
# 407    1
# 408    0
# 409    0
# 410    0
# 411    0
# 412    0
# 413    1
# 414    0
# 415    1
# 416    1
# 417    1
# Name: Sex, Length: 418, dtype: int64

# %%
df16['fare_new'] = df16['Fare'].apply(lambda x: x / 3)

# %%
df16.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked  Sex_new  fare_new
# 0  34.5      0      0   330911   7.8292   NaN        Q        1  2.609733
# 1  47.0      1      0   363272   7.0000   NaN        S        0  2.333333
# 2  62.0      0      0   240276   9.6875   NaN        Q        1  3.229167
# 3  27.0      0      0   315154   8.6625   NaN        S        1  2.887500
# 4  22.0      1      1  3101298  12.2875   NaN        S        0  4.095833

# %% [markdown]
# ### apply 대신 map 적용하는 경우
#
# * map을 적용하기 전에 mapping에 사용할 Dictionary 를 먼저 정의한다.

# %%
df16.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 13 columns):
# PassengerId    418 non-null int64
# Pclass         418 non-null int64
# Name           418 non-null object
# Sex            418 non-null object
# Age            418 non-null float64
# SibSp          418 non-null int64
# Parch          418 non-null int64
# Ticket         418 non-null object
# Fare           417 non-null float64
# Cabin          91 non-null object
# Embarked       418 non-null object
# Sex_new        418 non-null int64
# fare_new       417 non-null float64
# dtypes: float64(3), int64(5), object(5)
# memory usage: 42.5+ KB

# %%
my_map = {
    'female': 0,
    'male': 1
}

# %%
df16['Sex'].map(my_map)
# Out:
# 0      1
# 1      0
# 2      1
# 3      1
# 4      0
# 5      1
# 6      0
# 7      1
# 8      0
# 9      1
# 10     1
# 11     1
# 12     0
# 13     1
# 14     0
# 15     0
# 16     1
# 17     1
# 18     0
# 19     0
# 20     1
# 21     1
# 22     0
# 23     1
# 24     0
# 25     1
# 26     0
# 27     1
# 28     1
# 29     1
#       ..
# 388    1
# 389    1
# 390    1
# 391    0
# 392    1
# 393    1
# 394    1
# 395    0
# 396    1
# 397    0
# 398    1
# 399    1
# 400    0
# 401    1
# 402    0
# 403    1
# 404    1
# 405    1
# 406    1
# 407    1
# 408    0
# 409    0
# 410    0
# 411    0
# 412    0
# 413    1
# 414    0
# 415    1
# 416    1
# 417    1
# Name: Sex, Length: 418, dtype: int64

# %% [markdown]
# ## 4-6-8 : DataFrame 산술연산

# %%
import numpy as np

# %%
df17 = pd.DataFrame({'수학': [63, 71, 82, 86, 95], '영어': [60, 52, 88, 99, 100], '국어': [69, 78, 51, 100, 95] })

# %%
df17
# Out:
#    수학   영어   국어
# 0  63   60   69
# 1  71   52   78
# 2  82   88   51
# 3  86   99  100
# 4  95  100   95

# %% [markdown]
# ### Column 과 Column  산술연산 (+, -, *, /, //, %)

# %%
type(df17['수학'])
# Out:
# pandas.core.series.Series

# %%
df17['수학'] + df17['영어']
# Out:
# 0    123
# 1    123
# 2    170
# 3    185
# 4    195
# dtype: int64

# %%
df17['수학'] - df17['영어']
# Out:
# 0     3
# 1    19
# 2    -6
# 3   -13
# 4    -5
# dtype: int64

# %%
df17['수학'] * df17['영어']
# Out:
# 0    3780
# 1    3692
# 2    7216
# 3    8514
# 4    9500
# dtype: int64

# %%
df17['수학'] / df17['영어']
# Out:
# 0    1.050000
# 1    1.365385
# 2    0.931818
# 3    0.868687
# 4    0.950000
# dtype: float64

# %%
df17['수학'] // df17['영어']
# Out:
# 0    1
# 1    1
# 2    0
# 3    0
# 4    0
# dtype: int64

# %%
df17['수학'] % df17['영어']
# Out:
# 0     3
# 1    19
# 2    82
# 3    86
# 4    95
# dtype: int64

# %%
df17['합계'] = df17['수학'] + df17['영어'] + df17['국어'] + 5
df17
# Out:
#    수학   영어   국어   합계
# 0  63   60   69  197
# 1  71   52   78  206
# 2  82   88   51  226
# 3  86   99  100  290
# 4  95  100   95  295

# %% [markdown]
# ### mean(), sum()
#
# * axis 옵션 기준으로 연산

# %%
df17 = pd.DataFrame({'수학': [63, 71, 82, 86, 95], '영어': [60, 52, 88, 99, 100], '국어': [69, 78, 51, 100, 95] })

# %%
df17.sum(axis=0)
# Out:
# 수학    397
# 영어    399
# 국어    393
# dtype: int64

# %%
df17.mean(axis=0)
# Out:
# 수학    79.4
# 영어    79.8
# 국어    78.6
# dtype: float64

# %%
df17.sum(axis=1)
# Out:
# 0    192
# 1    201
# 2    221
# 3    285
# 4    290
# dtype: int64

# %%
df17.mean(axis=1)
# Out:
# 0    64.000000
# 1    67.000000
# 2    73.666667
# 3    95.000000
# 4    96.666667
# dtype: float64

# %% [markdown]
# ### 결측치(NaN) 이 존재할 경우 산술연산

# %%
df17 = pd.DataFrame({'수학': [63, np.nan, 82, 86, 95], '영어': [60, 52, np.nan, 99, 100], '국어': [69, 78, 51, 100, np.nan] })

# %%
df17
# Out:
#      수학     영어     국어
# 0  63.0   60.0   69.0
# 1   NaN   52.0   78.0
# 2  82.0    NaN   51.0
# 3  86.0   99.0  100.0
# 4  95.0  100.0    NaN

# %%
df17['수학'] / 2
# Out:
# 0    31.5
# 1     NaN
# 2    41.0
# 3    43.0
# 4    47.5
# Name: 수학, dtype: float64

# %%
200 / df17['수학']
# Out:
# 0    3.174603
# 1         NaN
# 2    2.439024
# 3    2.325581
# 4    2.105263
# Name: 수학, dtype: float64

# %%
df17['수학'] / np.nan
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# Name: 수학, dtype: float64

# %%
np.nan / df17['수학']
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# Name: 수학, dtype: float64

# %% [markdown]
# ### DataFrame 과 DataFrame 간 연산

# %%
df18 = pd.DataFrame({'수학': [63, 71, 82, 86, 95], '영어': [60, 52, 88, 99, 100], '국어': [69, 78, 51, 100, 95] })
df18
# Out:
#    수학   영어   국어
# 0  63   60   69
# 1  71   52   78
# 2  82   88   51
# 3  86   99  100
# 4  95  100   95

# %%
df19 = pd.DataFrame({'수학': ['A', 'A+', 'C', 'B', 'C-'], '영어': [50, 72, 84, 76, 100], '국어': [60, 88, 61, 90, 93] })
df19
# Out:
#    수학   영어  국어
# 0   A   50  60
# 1  A+   72  88
# 2   C   84  61
# 3   B   76  90
# 4  C-  100  93

# %% [markdown]
# #### 문자열이 포함된 DataFrame의 경우
# 에러발생 -> 문자열을 숫자형으로 바꾸어야 함.

# %%
df18 + df19
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/anaconda3/envs/kaggle/lib/python3.6/site-packages/pandas/core/ops.py in na_op(x, y)
#    1504         try:
# -> 1505             result = expressions.evaluate(op, str_rep, x, y, **eval_kwargs)
#    1506         except TypeError:
#
# ~/anaconda3/envs/kaggle/lib/python3.6/site-packages/pandas/core/computation/expressions.py in evaluate(op, op_str, a, b, use_numexpr, **eval_kwargs)
#     207     if use_numexpr:
# --> 208         return _evaluate(op, op_str, a, b, **eval_kwargs)
#     209     return _evaluate_standard(op, op_str, a, b)
#
# ~/anaconda3/envs/kaggle/lib/python3.6/site-packages/pandas/core/computation/expressions.py in _evaluate_standard(op, op_str, a, b, **eval_kwargs)
#      67     with np.errstate(all='ignore'):
# ---> 68         return op(a, b)
#      69
#
# ...

# %% [markdown]
# #### 문자열이 포함된 DataFrame의 Broadcasting 연산

# %%
df18 + 2
# Out:
#    수학   영어   국어
# 0  65   62   71
# 1  73   54   80
# 2  84   90   53
# 3  88  101  102
# 4  97  102   97

# %%
df19 + 2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/anaconda3/envs/kaggle/lib/python3.6/site-packages/pandas/core/ops.py in na_op(x, y)
#    1504         try:
# -> 1505             result = expressions.evaluate(op, str_rep, x, y, **eval_kwargs)
#    1506         except TypeError:
#
# ~/anaconda3/envs/kaggle/lib/python3.6/site-packages/pandas/core/computation/expressions.py in evaluate(op, op_str, a, b, use_numexpr, **eval_kwargs)
#     207     if use_numexpr:
# --> 208         return _evaluate(op, op_str, a, b, **eval_kwargs)
#     209     return _evaluate_standard(op, op_str, a, b)
#
# ~/anaconda3/envs/kaggle/lib/python3.6/site-packages/pandas/core/computation/expressions.py in _evaluate_standard(op, op_str, a, b, **eval_kwargs)
#      67     with np.errstate(all='ignore'):
# ---> 68         return op(a, b)
#      69
#
# TypeError: must be str, not int
#
# ...

# %% [markdown]
# #### column의 순서가 다른 DataFrame 간의 연산

# %%
df18 = pd.DataFrame({'수학': [63, 71, 82, 86, 95], '영어': [60, 52, 88, 99, 100], '국어': [69, 78, 51, 100, 95] })
df18
# Out:
#    수학   영어   국어
# 0  63   60   69
# 1  71   52   78
# 2  82   88   51
# 3  86   99  100
# 4  95  100   95

# %%
df19 = pd.DataFrame({'영어': [60, 52, 88, 99, 100], '수학': [63, 71, 82, 86, 95],  '국어': [69, 78, 51, 100, 95] })
df19
# Out:
#     영어  수학   국어
# 0   60  63   69
# 1   52  71   78
# 2   88  82   51
# 3   99  86  100
# 4  100  95   95

# %%
df18 + df19
# Out:
#     국어   수학   영어
# 0  138  126  120
# 1  156  142  104
# 2  102  164  176
# 3  200  172  198
# 4  190  190  200

# %% [markdown]
# #### Row 의 갯수가 서로 다른 DataFrame 간의 연산

# %%
df18 = pd.DataFrame({'수학': [63, 71, 82, 86, 95], '영어': [60, 52, 88, 99, 100], '국어': [69, 78, 51, 100, 95] })
df18
# Out:
#    수학   영어   국어
# 0  63   60   69
# 1  71   52   78
# 2  82   88   51
# 3  86   99  100
# 4  95  100   95

# %%
df19 = pd.DataFrame({'수학': [63, 71, 82, 86], '영어': [60, 52, 88, 99], '국어': [69, 78, 51, 100] })
df19
# Out:
#    수학  영어   국어
# 0  63  60   69
# 1  71  52   78
# 2  82  88   51
# 3  86  99  100

# %%
df18 + df19
# Out:
#       수학     영어     국어
# 0  126.0  120.0  138.0
# 1  142.0  104.0  156.0
# 2  164.0  176.0  102.0
# 3  172.0  198.0  200.0
# 4    NaN    NaN    NaN

# %% [markdown]
# ## 4-6-9 : select_dtypes
# 데이터 Type별 Column 선택

# %%
df20 = pd.read_csv(filename)

# %%
df20.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
# PassengerId    418 non-null int64
# Pclass         418 non-null int64
# Name           418 non-null object
# Sex            418 non-null object
# Age            332 non-null float64
# SibSp          418 non-null int64
# Parch          418 non-null int64
# Ticket         418 non-null object
# Fare           417 non-null float64
# Cabin          91 non-null object
# Embarked       418 non-null object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 36.0+ KB

# %% [markdown]
# ### 문자열이 있는 Column 만 선택

# %%
df20.select_dtypes(include='object')
# Out:
#                                                   Name     Sex  \
# 0                                     Kelly, Mr. James    male
# 1                     Wilkes, Mrs. James (Ellen Needs)  female
# 2                            Myles, Mr. Thomas Francis    male
# 3                                     Wirz, Mr. Albert    male
# 4         Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
# 5                           Svensson, Mr. Johan Cervin    male
# 6                                 Connolly, Miss. Kate  female
# 7                         Caldwell, Mr. Albert Francis    male
# 8            Abrahim, Mrs. Joseph (Sophie Halaut Easu)  female
# 9                              Davies, Mr. John Samuel    male
# 10                                    Ilieff, Mr. Ylio    male
# 11                          Jones, Mr. Charles Cresson    male
# 12       Snyder, Mrs. John Pillsbury (Nelle Stevenson)  female
# 13                                Howard, Mr. Benjamin    male
# ...

# %%
df20.select_dtypes(exclude='object')
# Out:
#      PassengerId  Pclass   Age  SibSp  Parch      Fare
# 0            892       3  34.5      0      0    7.8292
# 1            893       3  47.0      1      0    7.0000
# 2            894       2  62.0      0      0    9.6875
# 3            895       3  27.0      0      0    8.6625
# 4            896       3  22.0      1      1   12.2875
# 5            897       3  14.0      0      0    9.2250
# 6            898       3  30.0      0      0    7.6292
# 7            899       2  26.0      1      1   29.0000
# 8            900       3  18.0      0      0    7.2292
# 9            901       3  21.0      2      0   24.1500
# 10           902       3   NaN      0      0    7.8958
# 11           903       1  46.0      0      0   26.0000
# 12           904       1  23.0      1      0   82.2667
# 13           905       2  63.0      1      0   26.0000
# 14           906       1  47.0      1      0   61.1750
# 15           907       2  24.0      1      0   27.7208
# ...

# %%
df20 + 1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/anaconda3/envs/kaggle/lib/python3.6/site-packages/pandas/core/ops.py in na_op(x, y)
#    1504         try:
# -> 1505             result = expressions.evaluate(op, str_rep, x, y, **eval_kwargs)
#    1506         except TypeError:
#
# ~/anaconda3/envs/kaggle/lib/python3.6/site-packages/pandas/core/computation/expressions.py in evaluate(op, op_str, a, b, use_numexpr, **eval_kwargs)
#     207     if use_numexpr:
# --> 208         return _evaluate(op, op_str, a, b, **eval_kwargs)
#     209     return _evaluate_standard(op, op_str, a, b)
#
# ~/anaconda3/envs/kaggle/lib/python3.6/site-packages/pandas/core/computation/expressions.py in _evaluate_standard(op, op_str, a, b, **eval_kwargs)
#      67     with np.errstate(all='ignore'):
# ---> 68         return op(a, b)
#      69
#
# TypeError: must be str, not int
#
# ...

# %%
df20.select_dtypes(include='object') + 10
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/anaconda3/envs/kaggle/lib/python3.6/site-packages/pandas/core/ops.py in na_op(x, y)
#    1504         try:
# -> 1505             result = expressions.evaluate(op, str_rep, x, y, **eval_kwargs)
#    1506         except TypeError:
#
# ~/anaconda3/envs/kaggle/lib/python3.6/site-packages/pandas/core/computation/expressions.py in evaluate(op, op_str, a, b, use_numexpr, **eval_kwargs)
#     207     if use_numexpr:
# --> 208         return _evaluate(op, op_str, a, b, **eval_kwargs)
#     209     return _evaluate_standard(op, op_str, a, b)
#
# ~/anaconda3/envs/kaggle/lib/python3.6/site-packages/pandas/core/computation/expressions.py in _evaluate_standard(op, op_str, a, b, **eval_kwargs)
#      67     with np.errstate(all='ignore'):
# ---> 68         return op(a, b)
#      69
#
# TypeError: must be str, not int
#
# ...

# %%
df20.select_dtypes(exclude='object') + 10
# Out:
#      PassengerId  Pclass   Age  SibSp  Parch      Fare
# 0            902      13  44.5     10     10   17.8292
# 1            903      13  57.0     11     10   17.0000
# 2            904      12  72.0     10     10   19.6875
# 3            905      13  37.0     10     10   18.6625
# 4            906      13  32.0     11     11   22.2875
# 5            907      13  24.0     10     10   19.2250
# 6            908      13  40.0     10     10   17.6292
# 7            909      12  36.0     11     11   39.0000
# 8            910      13  28.0     10     10   17.2292
# 9            911      13  31.0     12     10   34.1500
# 10           912      13   NaN     10     10   17.8958
# 11           913      11  56.0     10     10   36.0000
# 12           914      11  33.0     11     10   92.2667
# 13           915      12  73.0     11     10   36.0000
# 14           916      11  57.0     11     10   71.1750
# 15           917      12  34.0     11     10   37.7208
# ...

# %%
number_cols = df20.select_dtypes(exclude='object').columns
object_cols = df20.select_dtypes(include='object').columns

# %%
df20[number_cols]
# Out:
#      PassengerId  Pclass   Age  SibSp  Parch      Fare
# 0            892       3  34.5      0      0    7.8292
# 1            893       3  47.0      1      0    7.0000
# 2            894       2  62.0      0      0    9.6875
# 3            895       3  27.0      0      0    8.6625
# 4            896       3  22.0      1      1   12.2875
# 5            897       3  14.0      0      0    9.2250
# 6            898       3  30.0      0      0    7.6292
# 7            899       2  26.0      1      1   29.0000
# 8            900       3  18.0      0      0    7.2292
# 9            901       3  21.0      2      0   24.1500
# 10           902       3   NaN      0      0    7.8958
# 11           903       1  46.0      0      0   26.0000
# 12           904       1  23.0      1      0   82.2667
# 13           905       2  63.0      1      0   26.0000
# 14           906       1  47.0      1      0   61.1750
# 15           907       2  24.0      1      0   27.7208
# ...

# %% [markdown]
# ## 4-6-10 : get_dummies
# One-Hot encoding을 해주는 메소드
#
# * One-Hot encoding : 한개의 요소는 1 그리고 나머지 요소는 0으로 만들어 주는 encoding 방법.
# * One-Hot encoding 의 용도 : 카테고리형 변수를 머신러닝 알고리즘에 One-Hot encoding 없이 그대로 주입하여 학습하게 되면 카테고리 값들간에 서로 종속되지 않고 영향을 주지 않음에도 불구하고, 마치 카테고리 값들간에 관계가 있는 것처럼 학습하게 된다. 요컨데 카테고리형 변수를 One-Hot encoding하면 카테고리 값의 갯수만큼 Column을 만들어 분리함으로서, 머신러닝 알고리즘이 카테고리 값마다의 독립적으로 학습할 수 있도록 해 준다.

# %%
df21 = pd.read_csv(filename)

# %%
df21.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
embarked_map = {
    'Q' : 1,
    'S' : 2,
    'C' : 3,
}

# %%
df21['Embarked_code'] = df['Embarked'].map(embarked_map)
df21.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked  Embarked_code
# 0  34.5      0      0   330911   7.8292   NaN        Q              1
# 1  47.0      1      0   363272   7.0000   NaN        S              2
# 2  62.0      0      0   240276   9.6875   NaN        Q              1
# 3  27.0      0      0   315154   8.6625   NaN        S              2
# 4  22.0      1      1  3101298  12.2875   NaN        S              2

# %%
df21['Embarked_code'].value_counts()
# Out:
# 2    270
# 3    102
# 1     46
# Name: Embarked_code, dtype: int64

# %%
df21['Embarked_code']
# Out:
# 0      1
# 1      2
# 2      1
# 3      2
# 4      2
# 5      2
# 6      1
# 7      2
# 8      3
# 9      2
# 10     2
# 11     2
# 12     2
# 13     2
# 14     2
# 15     3
# 16     1
# 17     3
# 18     2
# 19     3
# 20     3
# 21     2
# 22     2
# 23     3
# 24     3
# 25     2
# 26     3
# 27     3
# 28     2
# 29     3
#       ..
# 388    1
# 389    2
# 390    2
# 391    2
# 392    2
# 393    2
# 394    2
# 395    2
# 396    1
# 397    3
# 398    2
# 399    1
# 400    2
# 401    2
# 402    3
# 403    2
# 404    3
# 405    3
# 406    2
# 407    3
# 408    1
# 409    2
# 410    1
# 411    1
# 412    2
# 413    2
# 414    3
# 415    2
# 416    2
# 417    3
# Name: Embarked_code, Length: 418, dtype: int64

# %%
pd.get_dummies(df21['Embarked_code'])
# Out:
#      1  2  3
# 0    1  0  0
# 1    0  1  0
# 2    1  0  0
# 3    0  1  0
# 4    0  1  0
# 5    0  1  0
# 6    1  0  0
# 7    0  1  0
# 8    0  0  1
# 9    0  1  0
# 10   0  1  0
# 11   0  1  0
# 12   0  1  0
# 13   0  1  0
# 14   0  1  0
# 15   0  0  1
# 16   1  0  0
# 17   0  0  1
# 18   0  1  0
# 19   0  0  1
# 20   0  0  1
# 21   0  1  0
# 22   0  1  0
# 23   0  0  1
# 24   0  0  1
# 25   0  1  0
# 26   0  0  1
# 27   0  0  1
# 28   0  1  0
# 29   0  0  1
# ..  .. .. ..
# 388  1  0  0
# 389  0  1  0
# 390  0  1  0
# 391  0  1  0
# 392  0  1  0
# 393  0  1  0
# 394  0  1  0
# 395  0  1  0
# 396  1  0  0
# 397  0  0  1
# 398  0  1  0
# 399  1  0  0
# 400  0  1  0
# 401  0  1  0
# 402  0  0  1
# 403  0  1  0
# 404  0  0  1
# 405  0  0  1
# 406  0  1  0
# 407  0  0  1
# 408  1  0  0
# 409  0  1  0
# 410  1  0  0
# 411  1  0  0
# 412  0  1  0
# 413  0  1  0
# 414  0  0  1
# 415  0  1  0
# 416  0  1  0
# 417  0  0  1
#
# [418 rows x 3 columns]

# %%
pd.get_dummies(df21['Embarked_code'], prefix='Embarked')
# Out:
#      Embarked_1  Embarked_2  Embarked_3
# 0             1           0           0
# 1             0           1           0
# 2             1           0           0
# 3             0           1           0
# 4             0           1           0
# 5             0           1           0
# 6             1           0           0
# 7             0           1           0
# 8             0           0           1
# 9             0           1           0
# 10            0           1           0
# 11            0           1           0
# 12            0           1           0
# 13            0           1           0
# 14            0           1           0
# 15            0           0           1
# 16            1           0           0
# 17            0           0           1
# 18            0           1           0
# 19            0           0           1
# 20            0           0           1
# 21            0           1           0
# ...

# %% [markdown]
# # Lesson 4-7 Pandas Heuristics

# %% [markdown]
# ## 의미있는 이름을 사용할 것!
#
# * Good : users, users_cleaned, ratings_by_gender
# * Bad : df1, df2, a, b, temp
#
#
# 1. 이름을 보고 무엇인지 알 수 있도록...
# 2. 축약어는 지양할 것
# 3. 같은 이름을 다시 사용하지 말 것

# %% [markdown]
# ## 분석의 단계를 남길 것!
#
# * 분석단계1 : users
# * 분석단계2 : users_cleaned
# * 분석단계3 : users_sampled
# * 분석단계4 : users_added
#
#
# 1. 원본 데이터는 건드리지 말 것
# 2. 위에서부터 차례대로 실행가능하도록 할 것
# 3. 덜 중요한 과정은 Method Chaining으로 처리 할 것

# %% [markdown]
# ## for loop 을 사용하지 말 것!
#
# * map
# * apply
# * applymap
# * add
# * sub
# * mul
# * div
#
#
# 1. 위와 같은 method들로 99% for loop 대체 가능함.
